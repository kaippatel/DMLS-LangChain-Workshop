# %% [markdown]
# # **LangChain Chaining: Concepts and Examples**
#
# ## **📌 Overview**
# Chaining in LangChain allows for the **sequencing of multiple operations**, enabling more complex and structured \
# interactions with language models. By combining different processing steps, you can build advanced workflows \
# that enhance prompt flexibility and efficiency.
#
# In this section, we will cover key **chaining concepts**, including:
#
# - **Basic Chaining** – Linking multiple calls together in sequence using LangChain Expression Language (LCEL).
# - **Understanding Runnables** – The core building blocks for executing chains.
# - **Extended Processing** – Transforming and structuring responses dynamically.
# - **Parallel Processing** – Running multiple operations simultaneously for efficiency.
# - **Branching Processing** – Handling multiple decision paths based on input conditions.

# %%
# Install dependencies 
# %pip install -q python-dotenv langchain-core langchain-google-genai langchain
# %pip uninstall -y google-generativeai google-ai-generativelanguage
# %pip install -q google-generativeai==0.8.4 google-ai-generativelanguage==0.6.15
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: google-generativeai 0.8.4
# Uninstalling google-generativeai-0.8.4:
#   Successfully uninstalled google-generativeai-0.8.4
# Found existing installation: google-ai-generativelanguage 0.6.18
# Uninstalling google-ai-generativelanguage-0.6.18:
#   Successfully uninstalled google-ai-generativelanguage-0.6.18
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.1.1 requires google-ai-generativelanguage<0.7.0,>=0.6.16, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableLambda, RunnableSequence, RunnableParallel, RunnableBranch
from pathlib import Path

# %% [markdown]
# ## **Obtain a Google Gemini API Key (GOOGLE COLLAB SETUP):**
#
# If you have a Google Gemini API Key:
# - Copy your API key and replace "your_google_api_key_here" in the code below
#
# Otherwise:
# - Go to the Google AI Studio API Console: [Google AI Studio](https://aistudio.google.com/prompts/new_chat)
# - Sign in with your Google account and create a new API key.
# - Copy your API key and replace "your_google_api_key_here" in the code below

# %%
# Set your Google API key manually
import os
os.environ["GOOGLE_API_KEY"] = "your_google_api_key_here"

# %% [markdown]
# ## **Load Environment Variables (LOCAL SETUP)**

# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ---
#
# ## **SIDE NOTE**
#
# **Temperature** is a parameter used when sampling the next token from an LLM's probability distribution.
#
# In practice, temperature ranges from 0 < T < 2:
# - For **T = 0**, highest logit is given essentially 100% probability (**deterministic**).
# - For **0 < T < 1**, distribution is sharpened; high‑probability logits more likely and vice versa (**less randomness**).
# - For **T = 1**, model’s original softmax distribution without modification (**baseline randomness**).
# - For **T > 1**, distribution is flattened; gap between high‑ and low‑probability tokens shrinks (**more randomness**).
#
# As T increases, more randomness is introduced.
#
# For more information:
# - Amansinghalml, https://medium.com/%40amansinghalml_33304/temperature-llms-b41d75870510
# - Hopsworks, https://www.hopsworks.ai/dictionary/llm-temperature?utm_source=chatgpt.com

# %% [markdown]
# ---
#
# ## **Basic Chaining**
#
# Sequentially links components using LCEL for structured and reusable workflows.

# %%
# 1) Instantiate LLM 
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.2)

# 2) Define prompt template
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert travel guide. You create detailed, day-by-day itineraries " \
        "tailored to a traveler's interests."),
        ("human", "Create a {days}-day itinerary for a {interest} trip in {destination}."),
    ]
)
# 3) Create chain using LangChain Expression Langauge (LCEL)
chain = prompt_template | llm | StrOutputParser()

# 4) Get LLM response 
response = chain.invoke({
   "days": 30,
    "interest": "hiking",
    "destination": "South America"
})
print(response)

# ------------COMPARISON WITH MANUAL PROMPT FORMATTING------------

# Format prompt
prompt = prompt_template.invoke({
   "days": 30,
    "interest": "hiking",
    "destination": "South America"
})

# Get LLM response 
response = llm.invoke(prompt)
print(response.content)
# Out:
# ## 30-Day South American Hiking Adventure: A Challenging Itinerary
#
# This itinerary focuses on challenging hikes and stunning scenery, prioritizing physical fitness and a moderate to high level of experience.  It's crucial to assess your personal fitness level and hiking experience before embarking on this trip.  Acclimatization to altitude is vital, especially in the Andes.  Pre-booking accommodations and transportation is highly recommended, particularly during peak season.
#
# **Day 1-3: Arrival in Quito, Ecuador & Acclimatization**
#
# * Fly into Mariscal Sucre International Airport (UIO), Quito.
# * Spend three days acclimatizing to the altitude (approx. 9,350 ft).  Explore Quito's historic center (a UNESCO World Heritage site), enjoy the vibrant culture, and take short walks to gradually adjust to the altitude. Consider a visit to the Middle of the World monument.  Consult your doctor about altitude sickness prevention.
#
# **Day 4-7: Cotopaxi National Park & Quilotoa Loop**
#
# * Travel to Cotopaxi National Park. Hike around the base of Cotopaxi Volcano (optional: guided ascent for experienced mountaineers).
# * Embark on the Quilotoa Loop, a classic multi-day trek. This involves hiking between villages, experiencing local culture, and culminating in a breathtaking view of the Quilotoa crater lake.  Choose your level of difficulty (multi-day vs. shorter hikes).
#
# **Day 8-10: Travel to Baños & Tungurahua Volcano**
#
# * Travel from the Quilotoa Loop to Baños, a town known for its adventure activities.
# * Hike to viewpoints offering stunning perspectives of Tungurahua Volcano (check volcanic activity levels before attempting any close-up hikes).  Enjoy the hot springs and waterfalls in Baños.
#
# **Day 11-14: Fly to Cusco, Peru & Sacred Valley Trekking**
#
# * Fly from Quito to Cusco, Peru.  Spend a day acclimatizing to the altitude (approx. 11,152 ft) in Cusco.
# * Explore the Sacred Valley, choosing from various treks:  a shorter hike to Pisac ruins, or a more challenging trek to Ollantaytambo.  Consider a guided tour to learn about Inca history and culture.
#
# **Day 15-18: Inca Trail Trek to Machu Picchu (Permit Required)**
#
# * **Crucial:** Book your Inca Trail permits well in advance (months in advance is recommended). This is a challenging 4-day trek leading to the Sun Gate and Machu Picchu.  Choose a reputable tour operator with experienced guides.  Pack appropriately for varied weather conditions.
#
# **Day 19-20: Machu Picchu & Return to Cusco**
#
# * Explore Machu Picchu thoroughly.  Consider a guided tour to understand the history and significance of this iconic site.
# * Take the train back to Cusco from Aguas Calientes.
#
# **Day 21-23: Ausangate Trek (Optional, Challenging)**
#
# * For experienced hikers, consider the Ausangate Trek, a challenging multi-day trek in the Andes, offering stunning mountain scenery and high-altitude challenges.  This requires excellent physical fitness and proper acclimatization.  Hire a reputable guide and porter.
#
# **Day 24-26: Travel to Lake Titicaca & Isla del Sol**
#
# * Travel from Cusco to Puno, located on the shores of Lake Titicaca.
# * Take a boat to Isla del Sol, one of the largest islands on Lake Titicaca.  Hike around the island, exploring Inca ruins and enjoying breathtaking lake views.
#
# **Day 27-28: Travel to La Paz, Bolivia**
#
# * Travel from Puno to La Paz, Bolivia.  Explore the unique city of La Paz, situated in a high-altitude valley.
#
# **Day 29:  Death Road Mountain Biking (Optional)**
#
# * For adventure seekers, consider the Death Road mountain biking experience.  This is an adrenaline-pumping downhill ride, requiring a guided tour and appropriate safety gear.
#
# **Day 30: Departure from La Paz**
#
# * Depart from El Alto International Airport (LPB), La Paz.
#
#
# **Important Considerations:**
#
# * **Altitude Sickness:**  Acclimatization is crucial.  Ascend gradually, drink plenty of water, and be aware of symptoms.
# * **Permits & Bookings:**  Book flights, accommodation, and trekking permits well in advance, especially for popular treks like the Inca Trail.
# * **Gear:** Pack appropriate hiking gear, including sturdy boots, layers of clothing, rain gear, sunscreen, and a hat.
# * **Guides & Porters:**  Consider hiring a guide, especially for challenging treks.  For longer treks, hiring porters can significantly improve your experience.
# * **Health & Safety:** Consult your doctor about necessary vaccinations and medications.  Travel insurance is essential.
# * **Environmental Responsibility:**  Practice Leave No Trace principles and respect local communities and environments.
#
#
# This itinerary is a suggestion and can be customized based on your preferences, fitness level, and available time.  Remember to prioritize safety and enjoy the incredible beauty of South America's landscapes.
# ## 30-Day South American Hiking Adventure: A Challenging Itinerary
#
# This itinerary focuses on challenging hikes and stunning scenery, prioritizing physical fitness and a moderate to high level of experience.  It prioritizes the Andes and Patagonia, offering a diverse range of landscapes.  **This itinerary is ambitious and requires excellent physical fitness and prior hiking experience.**  Acclimatization is crucial, and altitude sickness should be taken seriously.  Consider consulting a doctor before embarking on this trip.
#
# **Pre-Trip Essentials:**
#
# * **Fitness:**  Extensive training beforehand is crucial.  Include high-altitude training if possible.
# * **Gear:** High-quality hiking boots, layers of clothing suitable for varied weather conditions (including rain gear), a large backpack (60-75L), sleeping bag rated for low temperatures, trekking poles, headlamps, water purification system, first-aid kit, and appropriate sun protection.
# * **Permits & Reservations:** Research and obtain necessary permits and book accommodations (refugios, hostels) in advance, especially during peak season.
# * **Travel Insurance:** Comprehensive travel insurance covering medical emergencies, evacuation, and lost gear is essential.
#
#
# **Day 1-4: Arrival in Quito, Ecuador & Acclimatization Hike (Cotopaxi National Park)**
#
# * Fly into Quito (UIO). Spend a day acclimatizing to the altitude (2,850m).
# * Transfer to Cotopaxi National Park (4,800m).  Hike around the base of Cotopaxi volcano, gradually increasing altitude.  Consider a shorter hike on day 1 and a longer one on day 2-3.  Stay in a refuge or nearby town.
#
# **Day 5-7:  Quilotoa Loop Trek, Ecuador**
#
# * Travel to the Quilotoa Loop. This 3-day trek takes you through stunning Andean villages, offering breathtaking views of the Quilotoa crater lake.  Stay in local communities along the way.
#
# **Day 8-10:  Fly to Cusco, Peru & Sacred Valley Acclimatization**
#
# * Fly from Quito to Cusco (CUZ), Peru.  Spend a day acclimatizing in Cusco (3,400m).  Explore the city and consider a short hike around the area to ease into the altitude.  Consider a visit to Sacsayhuamán.
#
# **Day 11-14: Inca Trail Trek (Permit Required, Book well in advance!)**
#
# * Embark on the classic Inca Trail trek to Machu Picchu (4-day trek). This requires permits booked months in advance.  Enjoy the stunning scenery and Inca ruins along the trail.  This is a challenging trek with significant altitude changes.
#
# **Day 15-16: Machu Picchu & Return to Cusco**
#
# * Explore Machu Picchu.  Take your time to appreciate the incredible history and views.  Return to Cusco by train.
#
# **Day 17-19:  Ausangate Trek, Peru (Optional, High Altitude)**
#
# * For experienced hikers, consider the challenging Ausangate trek (4-5 days). This trek takes you through high-altitude passes and stunning landscapes, offering views of the Ausangate mountain.  This requires excellent fitness and acclimatization.
#
# **Day 20-22: Fly to El Calafate, Argentina & Perito Moreno Glacier**
#
# * Fly from Cusco to El Calafate (FTE), Argentina.  Explore the Perito Moreno Glacier.  Consider a boat trip for closer views or a mini-trekking tour on the glacier (requires booking).
#
# **Day 23-25: Fitz Roy Trek, El Chalten, Argentina**
#
# * Travel to El Chalten, a trekking paradise.  Embark on a multi-day trek to Fitz Roy, offering challenging ascents and breathtaking views of this iconic mountain.  Choose a trek based on your experience level (Laguna de los Tres is a popular but challenging option).
#
# **Day 26-28:  Torres del Paine Circuit, Chile (Optional, Multi-Day)**
#
# * Travel to Torres del Paine National Park in Chile (requires crossing the border).  Embark on a portion of the famous W Trek or the full Circuit (5-7 days).  This is a challenging trek with varied landscapes, including glaciers, lakes, and mountains.  (Note: This requires extra days if doing the full circuit).
#
# **Day 29:  Return to El Calafate/Punta Arenas**
#
# * Depending on your chosen trek in Torres del Paine, return to El Calafate or travel to Punta Arenas (PUQ) for your departure.
#
# **Day 30: Departure**
#
# * Fly out from El Calafate or Punta Arenas.
#
#
# **Important Considerations:**
#
# * **Altitude Sickness:**  Acclimatization is crucial.  Ascend gradually, drink plenty of water, and be aware of symptoms.  Consult a doctor about altitude sickness medication.
# * **Weather:**  South American weather can be unpredictable.  Be prepared for all conditions, including rain, wind, and sun.
# * **Safety:**  Hike with a partner or group, inform someone of your plans, and carry appropriate safety gear.
# * **Environmental Responsibility:**  Leave no trace.  Pack out all your trash and respect the environment.
#
#
# This itinerary is a suggestion and can be adapted to your preferences and fitness level.  Remember to prioritize safety and enjoy the incredible beauty of the South American Andes and Patagonia!  Consider shortening or lengthening certain sections based on your available time and desired level of challenge.  Booking accommodations and permits well in advance is crucial, especially during peak season.

# %% [markdown]
# ## **Understanding Runnables**
# Defines execution logic within chains, enabling modular and reusable workflows.

# %%
# ......

# 3) Wrap each processing step in RunnableLambda 
format_prompt = RunnableLambda(lambda inputs: prompt_template.format_prompt(**inputs))
invoke_model = RunnableLambda(lambda prompt_val: llm.invoke(prompt_val.to_messages()))
parse_output = RunnableLambda(lambda llm_response: llm_response.content)

# 4a) Manually assemble chain
manual_chain = RunnableSequence(
    first=format_prompt, 
    middle=[invoke_model], 
    last=parse_output
)

# 4b) Or contruct using LCEL pipes
piped_chain = format_prompt | invoke_model | parse_output

# 5) Run chain (both 4a and 4b are the same!)
params = {
    "days": 30,
    "interest": "hiking",
    "destination": "South America"
}
manual_chain_response = manual_chain.invoke(params)
piped_chain_response = piped_chain.invoke(params)

print(f"-----Manual chain response-----\n: {manual_chain_response}\n\n")
print(f"-----Piped chain response-----\n: {piped_chain_response}")
# Out:
# -----Manual chain response-----
# : ## 30-Day South American Hiking Adventure: A Detailed Itinerary
#
# This itinerary focuses on a challenging yet rewarding hiking experience across diverse landscapes in South America, prioritizing iconic trails and stunning scenery.  It assumes a high level of fitness and experience with multi-day trekking.  Adjustments can be made based on your specific fitness level and preferences.  Always check weather conditions and trail closures before embarking on any hike.
#
# **Day 1-4:  Cusco & Acclimatization (Peru)**
#
# * **Day 1:** Arrive in Cusco (3400m/11,150ft).  Rest and acclimatize. Explore the city, visit San Blas artisan neighborhood, and enjoy a traditional Peruvian dinner.
# * **Day 2:**  Easy acclimatization hike around Cusco, perhaps to Sacsayhuamán, Q'enqo, Puka Pukara, and Tambomachay – Inca ruins offering stunning views.
# * **Day 3:**  Visit the Sacred Valley. Explore Ollantaytambo and Pisac, enjoying the markets and stunning scenery.  Consider a short hike in the valley.
# * **Day 4:**  Continue acclimatization with a longer hike in the Sacred Valley, perhaps a section of the Inca Trail alternative.
#
#
# **Day 5-9: Inca Trail Trek to Machu Picchu (Peru)**
#
# * **Day 5-8:**  Classic Inca Trail Trek (4 days/3 nights).  This requires permits booked well in advance.  Expect challenging terrain, high altitude, and stunning views.  A guide and porter are highly recommended.
# * **Day 9:**  Arrive at Machu Picchu. Explore the lost city of the Incas, marvel at the architecture, and soak in the breathtaking views. Take the bus down to Aguas Calientes and spend the night.
#
#
# **Day 10-12:  Huayhuash Circuit (Peru) - Preparation & Start**
#
# * **Day 10:** Travel from Aguas Calientes to Huaraz (high altitude, consider a flight).  Rest and prepare for the Huayhuash Circuit.  Purchase any necessary supplies.
# * **Day 11:**  Acclimatization hike near Huaraz.  This is crucial before tackling the Huayhuash.
# * **Day 12:**  Travel to the starting point of the Huayhuash Circuit (e.g., Llamac).
#
#
# **Day 13-20: Huayhuash Circuit (Peru)**
#
# * **Day 13-20:**  Trek the Huayhuash Circuit (7-8 days). This is a challenging trek with high passes, stunning mountain scenery, and remote villages.  A guide and pack animals are strongly recommended.  This itinerary requires careful planning and preparation, including sufficient food and water.  Expect varying weather conditions.
#
#
# **Day 21-23:  Travel & Rest (Peru/Chile)**
#
# * **Day 21:** Travel from the end of the Huayhuash Circuit back to Huaraz, then fly to Santiago, Chile.
# * **Day 22:** Explore Santiago. Visit the city center, enjoy the parks, and acclimatize to a lower altitude.
# * **Day 23:**  Travel to the starting point of your chosen Chilean trek (e.g., Torres del Paine).
#
#
# **Day 24-29: Torres del Paine Circuit (Chile)**
#
# * **Day 24-29:**  Trek the "W" Trek or the full "O" Circuit in Torres del Paine National Park (5-6 days).  This is a popular trek with stunning glaciers, lakes, and mountains.  Camping is common, but refugios (mountain huts) are available for booking.  Expect varied weather conditions, including strong winds.
#
#
# **Day 30: Departure**
#
# * Travel from Torres del Paine to Punta Arenas for your departure flight.
#
#
# **Important Considerations:**
#
# * **Permits & Bookings:**  Inca Trail permits require booking months in advance.  Huayhuash Circuit requires careful planning and potentially a guide.  Torres del Paine requires booking campsites or refugios.
# * **Altitude Sickness:**  Acclimatization is crucial.  Ascend gradually and listen to your body.  Consult a doctor about altitude sickness prevention.
# * **Gear:**  Pack appropriate clothing and gear for varied weather conditions, including rain gear, warm layers, sturdy hiking boots, and a backpack.
# * **Guides & Porters:**  Consider hiring a guide and/or porter, especially for the Inca Trail and Huayhuash Circuit.  They enhance safety and provide valuable local knowledge.
# * **Health & Safety:**  Consult your doctor about necessary vaccinations and travel insurance.  Be aware of potential risks and take necessary precautions.
# * **Flexibility:**  This is a challenging itinerary.  Be prepared to adjust the schedule based on weather conditions, fitness levels, and unforeseen circumstances.
#
#
# This itinerary provides a framework.  You can customize it based on your interests, fitness level, and available time.  Remember to research thoroughly and plan meticulously for a safe and unforgettable South American hiking adventure.
#
#
# -----Piped chain response-----
# : ## 30-Day South American Hiking Adventure: Patagonia & Andes Exploration
#
# This itinerary focuses on Patagonia and the Andes, prioritizing challenging yet rewarding hikes with stunning scenery.  It assumes a high level of fitness and experience with multi-day trekking.  Adjust difficulty and duration based on your personal capabilities.  Pre-booking accommodations and transportation, especially in peak season, is crucial.
#
# **Day 1-4: Arrival in El Calafate, Argentina & Perito Moreno Glacier Trek**
#
# * Fly into El Calafate (FTE).  Settle into your accommodation.
# * **Day 2:** Explore El Calafate town.  Optional: Mini-trekking on the glacier's lower trails.
# * **Day 3-4:**  Big Ice Trek on Perito Moreno Glacier (full-day guided tour). This involves crampons and ice axes.  Consider a more challenging trek if your experience allows.
#
# **Day 5-8: El Chalten & Fitz Roy Trek**
#
# * Bus from El Calafate to El Chalten (approx. 3 hours).
# * **Day 6-7:**  Laguna de los Tres Trek (challenging, full-day).  This iconic trek offers breathtaking views of Mount Fitz Roy.  Consider camping overnight for a more immersive experience (requires permits).
# * **Day 8:**  Laguna Torre Trek (moderate, full-day).  Offers stunning views of Cerro Torre and its surrounding glaciers.
#
# **Day 9-12: Torres del Paine National Park, Chile**
#
# * Bus from El Chalten to Puerto Natales, Chile (border crossing involved).
# * **Day 10-12:**  W Trek in Torres del Paine (multi-day trek, 4-5 days depending on chosen pace).  This classic trek offers diverse landscapes, including glaciers, lakes, and mountains.  Choose between camping or staying in refugios (pre-booking essential).
#
# **Day 13-15: Puerto Natales & Grey Glacier**
#
# * **Day 13:**  Travel from Torres del Paine to Puerto Natales. Explore the charming town.
# * **Day 14-15:**  Grey Glacier boat tour.  Enjoy stunning views of the glacier from the water.  Optional kayaking tour available.
#
# **Day 16-19:  Fly to Santiago & Andes Trekking (Central Chile)**
#
# * Fly from Punta Arenas (PUQ) to Santiago (SCL).
# * Transfer to a chosen trekking location in the Andes near Santiago (e.g., Cajón del Maipo).
# * **Day 17-18:**  Multi-day trek in the Andes.  Choose a trek based on your fitness level and preferences.  Many options exist, ranging from moderate day hikes to challenging multi-day treks.  Consider hiring a guide for remote areas.
# * **Day 19:**  Return to Santiago.
#
# **Day 20-23:  Fly to Cusco, Peru & Acclimatization**
#
# * Fly from Santiago (SCL) to Cusco (CUZ), Peru.  Allow time for acclimatization to the altitude (Cusco is at a high elevation).
# * **Day 20-21:**  Rest and explore Cusco.  Visit historical sites, markets, and enjoy the city's atmosphere.  Consider a guided tour to learn about Inca history.
# * **Day 22-23:**  Acclimatization hikes around Cusco.  Gradually increase altitude to avoid altitude sickness.
#
# **Day 24-27: Inca Trail Trek (or alternative)**
#
# * **Option 1 (Inca Trail):**  Inca Trail Trek to Machu Picchu (requires permits booked well in advance, 4 days/3 nights).  This classic trek offers stunning views and Inca ruins.  A guide and porter are recommended.
# * **Option 2 (Alternative Treks):**  Salkantay Trek, Inca Jungle Trek, or other alternative treks to Machu Picchu.  These offer different landscapes and experiences.
#
# **Day 28: Machu Picchu Exploration**
#
# * Explore the magnificent Machu Picchu citadel.  Consider a guided tour to learn about its history and significance.  Take the bus down to Aguas Calientes.
#
# **Day 29: Return Journey**
#
# * Train from Aguas Calientes to Ollantaytambo, then bus to Cusco.  Fly from Cusco (CUZ) to your next destination or home.
#
# **Day 30: Departure**
#
# * Depart from Cusco or Lima (LIM).
#
#
# **Important Considerations:**
#
# * **Altitude Sickness:**  Acclimatization is crucial for high-altitude treks.  Ascend gradually and drink plenty of water.
# * **Permits & Bookings:**  Many treks require permits and pre-booking of accommodations (refugios or campsites).  Book well in advance, especially during peak season.
# * **Gear:**  Pack appropriate clothing and gear for varying weather conditions, including waterproof and warm layers, sturdy hiking boots, and a backpack.
# * **Guides & Porters:**  Consider hiring a guide, especially for challenging treks or remote areas.  Porters can help carry your gear.
# * **Insurance:**  Comprehensive travel insurance is essential, covering medical emergencies, evacuation, and lost belongings.
# * **Vaccinations & Health:**  Consult your doctor about necessary vaccinations and health precautions.
#
#
# This itinerary is a suggestion and can be customized to your preferences and fitness level.  Remember to research thoroughly and plan accordingly for a safe and unforgettable South American hiking adventure.

# %%
# Run chain
response = piped_chain.invoke({
    "days": 30,
    "interest": "hiking",
    "destination": "South America"
})
print(response)

#----------Either way, when we run chain....

# 1st runnable
prompt_val = prompt_template.format_prompt(
    days=30,
    interest="hiking",
    destination="South America"
)
print(prompt_val)
# prompt_val is holds structured SYSTEM + HUMAN messages

# 2nd runnable
messages = prompt_val.to_messages()
print(messages)
# messages transforms prompt_val into list of chat messages

llm_response = llm.invoke(messages)
# llm_response returns LLM response containing content and metadata 

# 3rd runnable
parse_output = llm_response.content
# parse_output extracts the content from the llm_response

print(parse_output)
# Out:
# ## 30-Day South American Hiking Adventure: A Challenging Itinerary
#
# This itinerary focuses on challenging hikes and stunning scenery, prioritizing physical fitness and a moderate to high level of experience.  It prioritizes the Andes and Patagonia, but can be adapted based on your specific fitness level and preferences.  **Always check weather conditions and trail closures before embarking on any hike.**  Consider hiring a local guide for some sections, especially in more remote areas.
#
# **Pre-Trip Essentials:**
#
# * **Fitness:**  Train extensively beforehand. This itinerary involves significant elevation gain and strenuous daily hikes.
# * **Gear:** High-quality hiking boots, layers of clothing suitable for varied weather, rain gear, backpack (50-70L), sleeping bag (depending on altitude), tent (if camping), water filter/purifier, first-aid kit, sun protection, insect repellent.
# * **Permits & Visas:** Research necessary permits for national parks and ensure your passport has sufficient validity.
# * **Travel Insurance:** Comprehensive travel insurance covering medical emergencies, evacuation, and lost gear is crucial.
# * **Spanish:** While English is spoken in tourist areas, learning basic Spanish will greatly enhance your experience.
#
#
# **Day 1-7: Ecuador – Cotopaxi & Quilotoa Loop**
#
# * **Day 1-2:** Arrive in Quito, acclimatize to the altitude.  Explore the city's historic center.
# * **Day 3-4:** Hike Cotopaxi National Park.  Choose from various trails depending on your fitness level, potentially including a climb to the refuge.  Acclimatization is key here.
# * **Day 5-7:** Quilotoa Loop Trek (3-4 days). This challenging trek takes you through stunning Andean landscapes, including the iconic Quilotoa crater lake.  Consider staying in local communities for an authentic experience.
#
#
# **Day 8-14: Peru – Inca Trail to Machu Picchu (Alternative: Salkantay Trek)**
#
# * **Day 8-9:** Travel from Ecuador to Cusco, Peru.  Spend time acclimatizing to the altitude.
# * **Day 10-14:** Inca Trail Trek to Machu Picchu (4 days/3 nights) – requires permits booked well in advance.  This classic trek offers breathtaking views and Inca ruins.  Alternatively, consider the Salkantay Trek, a more challenging but less crowded option.  Remember to book your train tickets to Aguas Calientes in advance.  Explore Machu Picchu on Day 14.
#
#
# **Day 15-21: Patagonia – Torres del Paine, Chile**
#
# * **Day 15-16:** Fly from Cusco to Punta Arenas, Chile.  Travel to Torres del Paine National Park.
# * **Day 17-21:**  W Trek (5 days/4 nights) in Torres del Paine. This iconic trek offers incredible views of the granite towers, glaciers, and lakes.  Camping is common, but refugios (mountain huts) are available for booking.  This is a demanding trek with significant daily distances and elevation changes.
#
#
# **Day 22-28: Patagonia – Fitz Roy & Cerro Torre, Argentina**
#
# * **Day 22-23:** Travel from Torres del Paine to El Chalten, Argentina.
# * **Day 24-27:** Explore the trails around El Chalten, focusing on hikes to Fitz Roy and Cerro Torre.  Choose trails based on your fitness and time constraints.  These hikes can be long and challenging, with significant elevation gain.
# * **Day 28:** Travel from El Chalten to a larger city like El Calafate for easier onward travel.
#
#
# **Day 29-30: Departure**
#
# * **Day 29:**  Depending on your flight schedule, you might have time for some last-minute souvenir shopping or exploring the city.
# * **Day 30:** Depart from El Calafate (or another chosen airport)
#
#
# **Important Considerations:**
#
# * **Altitude Sickness:**  Acclimatization is crucial.  Ascend gradually and listen to your body.  Consult a doctor about altitude sickness medication if necessary.
# * **Weather:**  Patagonia's weather is notoriously unpredictable.  Be prepared for all conditions, including strong winds, rain, and snow.
# * **Wildlife:**  Be aware of potential wildlife encounters, such as pumas in Patagonia.  Follow safety guidelines and maintain a safe distance.
# * **Environmental Responsibility:**  Pack out all trash, stay on marked trails, and respect the environment.
#
#
# This itinerary is a suggestion and can be customized to your preferences and fitness level.  You might choose to spend more time in certain areas or substitute different treks.  Remember to thoroughly research each location and book accommodations and permits in advance, especially during peak season.  Enjoy your incredible South American hiking adventure!
# messages=[SystemMessage(content="You are an expert travel guide. You create detailed, day-by-day itineraries tailored to a traveler's interests.", additional_kwargs={}, response_metadata={}), HumanMessage(content='Create a 30-day itinerary for a hiking trip in South America.', additional_kwargs={}, response_metadata={})]
# [SystemMessage(content="You are an expert travel guide. You create detailed, day-by-day itineraries tailored to a traveler's interests.", additional_kwargs={}, response_metadata={}), HumanMessage(content='Create a 30-day itinerary for a hiking trip in South America.', additional_kwargs={}, response_metadata={})]
# ## 30-Day South American Hiking Adventure: A Detailed Itinerary
#
# This itinerary focuses on a challenging yet rewarding hiking experience across diverse landscapes in Patagonia and the Andes.  It prioritizes stunning scenery and varied trekking experiences, but requires a high level of fitness and preparedness.  **Prior experience with multi-day backpacking is essential.**  This itinerary is a suggestion and can be adjusted based on your specific fitness level and preferences.  Always check weather conditions and trail closures before embarking on any hike.
#
# **Day 1-4: Arrival in El Calafate & Fitz Roy Trek (Argentina)**
#
# * Fly into El Calafate (FTE), Argentina.  Acclimatize to the altitude.
# * Transfer to El Chalten, the trekking capital of Patagonia.
# * **Day 2-4:**  Embark on a multi-day trek to Fitz Roy and Cerro Torre.  This involves several days of strenuous hiking with significant elevation gain.  Consider booking a guided tour for safety and logistical support, especially if you're unfamiliar with the area.  Choose a route based on your fitness level – options range from shorter day hikes to longer, more challenging multi-day treks.  Camping is common on these treks.
#
# **Day 5-7: El Chalten Exploration & Relaxation**
#
# * Rest and recover in El Chalten.
# * Explore shorter trails around El Chalten, such as Laguna de los Tres (shorter version if needed after Fitz Roy trek) or Loma del Pliegue Tumbado for stunning views.
# * Enjoy the town's atmosphere, relax, and resupply for the next leg of the journey.
#
# **Day 8-12: Torres del Paine National Park (Chile)**
#
# * Travel from El Chalten to Puerto Natales, Chile (bus journey).
# * Transfer to Torres del Paine National Park.
# * **Day 9-12:**  Choose a trekking circuit within Torres del Paine.  The "W" trek is the most popular, offering iconic views of the Paine Massif, Grey Glacier, and French Valley.  The "O" circuit is longer and more challenging, encompassing the entire park.  Consider booking campsites in advance, especially during peak season.  Pack appropriate gear for all weather conditions.
#
# **Day 13-14: Travel to San Pedro de Atacama (Chile)**
#
# * Travel from Torres del Paine to Punta Arenas (bus).
# * Fly from Punta Arenas to Calama, then transfer to San Pedro de Atacama.  This involves a long travel day.
#
# **Day 15-18: Atacama Desert Hiking & Exploration (Chile)**
#
# * Acclimatize to the high altitude of the Atacama Desert.
# * Hike to Valle de la Luna (Moon Valley) and Valle de la Muerte (Death Valley) for breathtaking landscapes.
# * Consider a day trip to El Tatio Geysers, witnessing the sunrise over active geysers.
# * Explore the salt flats of Salar de Atacama and visit the charming town of San Pedro de Atacama.
#
# **Day 19-22: Inca Trail Trek (Peru) – Preparation & Acclimatization**
#
# * Fly from Calama to Cusco, Peru.  This is a significant altitude change, so allow time for acclimatization.
# * Spend a few days in Cusco, exploring the city and getting ready for the Inca Trail.  Consider a guided tour for the Inca Trail.  Book well in advance, as permits are limited.
# * Engage in acclimatization hikes around Cusco to reduce the risk of altitude sickness.
#
# **Day 23-26: Inca Trail Trek to Machu Picchu (Peru)**
#
# * **Day 23-26:**  Embark on the classic Inca Trail trek to Machu Picchu.  This is a challenging 4-day trek, requiring a high level of fitness.  You'll be camping along the trail and experiencing incredible Inca ruins and breathtaking mountain scenery.  A guided tour is highly recommended.
#
# **Day 27: Machu Picchu Exploration**
#
# * Explore the magnificent Machu Picchu citadel.  Take your time to appreciate the history and beauty of this iconic site.  Consider a guided tour to learn more about the history and significance of the site.
#
# **Day 28: Return to Cusco & Relaxation**
#
# * Take the train back from Aguas Calientes (Machu Picchu town) to Ollantaytambo, then a bus to Cusco.
# * Relax and recover in Cusco.
#
# **Day 29: Cusco Exploration & Departure Preparation**
#
# * Explore Cusco further, visiting museums, markets, and other historical sites.
# * Prepare for your departure.
#
# **Day 30: Departure from Cusco (CUZ)**
#
# * Fly out of Cusco (CUZ).
#
#
# **Important Notes:**
#
# * **Fitness Level:** This itinerary demands a high level of physical fitness.  Train extensively before your trip, focusing on endurance and altitude training.
# * **Altitude Sickness:** Be aware of the risks of altitude sickness and take necessary precautions.  Acclimatize gradually and consult your doctor about altitude sickness medication.
# * **Permits & Bookings:**  Book flights, accommodation, and trekking permits well in advance, especially for popular trails like the Inca Trail.
# * **Gear:** Pack appropriate clothing and gear for diverse climates and terrains, including layers for varying temperatures, waterproof and windproof outerwear, sturdy hiking boots, and a good backpack.
# * **Safety:**  Inform someone of your itinerary and expected return dates.  Consider travel insurance that covers medical emergencies and evacuations.  Be aware of potential hazards, such as weather changes, wildlife encounters, and trail conditions.
#
#
# This itinerary is a suggestion, and you can customize it based on your preferences and fitness level.  Remember to prioritize safety and enjoy the incredible beauty of South America's landscapes!

# %% [markdown]
# ## **Extended Processing**
# Transforms and structures responses for enhanced output customization.

# %%
# Instantiate LLM 
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.2)

# ----Define prompt templates------------------------
action_template = ChatPromptTemplate.from_messages([
    ("system", "You extract action items from a meeting transcript."),
    ("human", "List the action items for this meeting transcript," \
        "as bullet points, each starting with '- ':\n\n{text}")
])

# ----Create runnables------------------------
extract_actions = RunnableLambda(
    lambda summary_data: {
        "title": summary_data["title"],
        "actions": llm.invoke(
            action_template.format_prompt(
                text=summary_data["text"]
            ).to_messages()
        ).content.strip()
    }
)

parse_actions = RunnableLambda(
    lambda actions_data: {
        "title": actions_data["title"], 
        "actions": [line.strip("- ").strip()
            for line in actions_data["actions"].splitlines()
            if line.strip().startswith("-")]
    }
) 

# ----Assemble chain------------------------
chain = extract_actions | parse_actions

meeting_title = "Business Meeting 2025-05-01"
meeting_text = """Alice: Good morning, team. Let's get started on our Q3 marketing campaign planning. \n Bob: Morning, Alice. First up, we need to finalize the campaign budget. I've drafted a spreadsheet with three scenarios (low, medium, high spend) and emailed it to everyone. \n Charlie: Got it—Bob, can you share that in the #marketing Slack channel by end of day? \nBob: Yes, I'll post it there by 5 PM today.\n Alice: Great. Next, social media strategy. Dana, you were going to propose some new platforms for influencer outreach?\n Dana: Right. I'm evaluating two micr\n Emily: On it. I'll draft initial outreach emails and share a template by Thursday.\n Alice: Finally, we need copy for the landing page. Frank, can you write the first draft?\n Frank: I'll draft the copy by Monday morning and circulate it for feedback.\n Alice: Awesome. Let's recap action items:\n - **Bob**: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.\n  - **Dana**: Deliver influencer-network recommendation deck by Wednesday.\n  - **Emily**: Share outreach email template by Thursday.\n    - **Frank**: Draft landing-page copy by Monday morning.\n  \nThanks, everyone—meeting adjourned!\n"""

# ----Run chain------------------------
response = chain.invoke({"title": meeting_title, "text": meeting_text})
print(f"Actions items for {response['title']}\n")
for action in response["actions"]: 
    print(action)
# Out:
# Actions items for Business Meeting 2025-05-01
#
# Bob: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.
# Dana: Deliver influencer-network recommendation deck by Wednesday.
# Emily: Share outreach email template by Thursday.
# Frank: Draft landing-page copy by Monday morning.

# %% [markdown]
# ## **EXERCISE**
# Modify the previous example to read in the generated txt file, output actions to a separate txt file, \
# and respond to the user with the path where the file was saved.
#
# 1. Read the file from path "/content/{meeting_title}.txt"
# 2. Output a new file at path "/content/{meeting_title}: Action Items.txt" (each action item on a new line)
# 3. Respond to the user with the file path
#
# ```bash
# # To read
# p = Path("content/MyMeeting.txt")
# text = p.read_text(encoding="utf-8")
#
# # To write
# p = Path("content/MyMeeting: Action Items.txt")
# p.write_text(actions, encoding="utf-8")
#
# # To join a list with new line characters
# "\n".join(lines)
# ```

# %%
# ... Previous runnables, templates, etc.

"""
HINT: It may help to define a single helper function that achieves TODO#2 
and combines logic for generating action items (i.e., extract_actions, parse_actions)

TODO#1 - create runnable to read the file 
TODO#2 - create runnable to write the generated actions to a new txt file 
TODO#3 - create runnable to respond to user 
TODO#4 - modify chain with the new runnables
"""

# ******************CODE HERE*****************

# ----Assemble chain------------------------
chain = extract_actions | parse_actions

# *******************DO NOT MODIFY BELOW*******************

# ----Generate txt file------------------------
meeting_title = "Business Meeting 2025-05-01"
meeting_text = """Alice: Good morning, team. Let's get started on our Q3 marketing campaign planning. \n Bob: Morning, Alice. First up, we need to finalize the campaign budget. I've drafted a spreadsheet with three scenarios (low, medium, high spend) and emailed it to everyone. \n Charlie: Got it—Bob, can you share that in the #marketing Slack channel by end of day? \nBob: Yes, I'll post it there by 5 PM today.\n Alice: Great. Next, social media strategy. Dana, you were going to propose some new platforms for influencer outreach?\n Dana: Right. I'm evaluating two micr\n Emily: On it. I'll draft initial outreach emails and share a template by Thursday.\n Alice: Finally, we need copy for the landing page. Frank, can you write the first draft?\n Frank: I'll draft the copy by Monday morning and circulate it for feedback.\n Alice: Awesome. Let's recap action items:\n - **Bob**: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.\n  - **Dana**: Deliver influencer-network recommendation deck by Wednesday.\n  - **Emily**: Share outreach email template by Thursday.\n    - **Frank**: Draft landing-page copy by Monday morning.\n  \nThanks, everyone—meeting adjourned!\n"""

Path("content").mkdir(parents=True, exist_ok=True)

p = Path(f"content/{meeting_title}.txt")
p.write_text(meeting_text, encoding="utf-8")

# ----Run chain------------------------
response = chain.invoke({"title": meeting_title})
print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 26
#      23 p.write_text(meeting_text, encoding="utf-8")
#      25 # ----Run chain------------------------
# ---> 26 response = chain.invoke({"title": meeting_title})
#      27 print(response)
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:3023, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3021 with set_config_context(config) as context:
#    3022     if i == 0:
# -> 3023         input = context.run(step.invoke, input, config, **kwargs)
#    3024     else:
#    3025         input = context.run(step.invoke, input, config)
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:4719, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4705 """Invoke this Runnable synchronously.
#    4706
#    4707 Args:
#    (...)   4716     TypeError: If the Runnable is a coroutine function.
#    4717 """
#    4718 if hasattr(self, "func"):
# -> 4719     return self._call_with_config(
#    4720         self._invoke,
#    4721         input,
#    4722         self._config(config, self.func),
#    4723         **kwargs,
#    4724     )
#    4725 else:
#    4726     msg = (
#    4727         "Cannot invoke a coroutine function synchronously."
#    4728         "Use `ainvoke` instead."
#    4729     )
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:1925, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1921     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1922     with set_config_context(child_config) as context:
#    1923         output = cast(
#    1924             Output,
# -> 1925             context.run(
#    1926                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1927                 func,  # type: ignore[arg-type]
#    1928                 input,  # type: ignore[arg-type]
#    1929                 config,
#    1930                 run_manager,
#    1931                 **kwargs,
#    1932             ),
#    1933         )
#    1934 except BaseException as e:
#    1935     run_manager.on_chain_error(e)
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:4573, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    4571                 output = chunk
#    4572 else:
# -> 4573     output = call_func_with_variable_args(
#    4574         self.func, input, config, run_manager, **kwargs
#    4575     )
#    4576 # If the output is a Runnable, invoke it
#    4577 if isinstance(output, Runnable):
#
# File ~/dev/dmls-langchain-workshop/.venv/lib/python3.11/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# Cell In[105], line 30, in create_actions(data)
#      28 def create_actions(data):
#      29     response = llm.invoke(
# ---> 30         action_template.format_prompt(text=data["text"]).to_messages()
#      31     ).content.strip()
#      32     action_items = [
#      33         line.strip("- ").strip()
#      34         for line in response.splitlines()
#      35         if line.strip().startswith("-")
#      36     ]
#      38     return {
#      39         "title": data["title"],
#      40         "actions": action_items
#      41     }
#
# KeyError: 'text'

# %%
"""..................................................................."""

# %%
"""..................................................................."""

# %%
""".......................SOLUTION BELOW.............................."""

# %%
"""..................................................................."""

# %%
"""..................................................................."""

# %% [markdown]
# ## **SOLUTION**

# %%
# Instantiate LLM 
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.2)

# ----Define prompt templates------------------------
action_template = ChatPromptTemplate.from_messages([
    ("system", "You extract action items from a meeting transcript."),
    ("human", "List the action items for this meeting transcript," \
        "as bullet points, each starting with '- ':\n\n{text}")
])

# ----Helper functions------------------------
def create_actions(data): 
    response = llm.invoke(
        action_template.format_prompt(text=data["text"]).to_messages()
    ).content.strip()
    
    action_items = [
        line.strip("- ").strip()
        for line in response.splitlines()
        if line.strip().startswith("-")
    ]

    return {"title": data["title"], "actions": action_items}

def actions_to_txt(data):
    title = data["title"]
    actions = data["actions"]
    
    # Write actions 
    p = Path(f"content/{title}: Action Items.txt")
    p.write_text("\n".join(actions), encoding="utf-8")
    return str(p) # return path for confirmation message

# ----Create runnables------------------------
load_transcript = RunnableLambda(
    lambda inputs: {
        "title": inputs["title"],
        "text":  Path(f"content/{inputs['title']}.txt").read_text(encoding="utf-8")
    }
)
extract_actions = RunnableLambda(create_actions)
write_actions = RunnableLambda(actions_to_txt)
respond_to_user = RunnableLambda(lambda path: f"Action items saved to {path}")

# ----Assemble chain------------------------
chain = load_transcript | extract_actions | write_actions | respond_to_user

# ----Generate txt file------------------------
meeting_title = "Business Meeting 2025-05-01"
meeting_text = """Alice: Good morning, team. Let's get started on our Q3 marketing campaign planning. \n Bob: Morning, Alice. First up, we need to finalize the campaign budget. I've drafted a spreadsheet with three scenarios (low, medium, high spend) and emailed it to everyone. \n Charlie: Got it—Bob, can you share that in the #marketing Slack channel by end of day? \nBob: Yes, I'll post it there by 5 PM today.\n Alice: Great. Next, social media strategy. Dana, you were going to propose some new platforms for influencer outreach?\n Dana: Right. I'm evaluating two micr\n Emily: On it. I'll draft initial outreach emails and share a template by Thursday.\n Alice: Finally, we need copy for the landing page. Frank, can you write the first draft?\n Frank: I'll draft the copy by Monday morning and circulate it for feedback.\n Alice: Awesome. Let's recap action items:\n - **Bob**: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.\n  - **Dana**: Deliver influencer-network recommendation deck by Wednesday.\n  - **Emily**: Share outreach email template by Thursday.\n    - **Frank**: Draft landing-page copy by Monday morning.\n  \nThanks, everyone—meeting adjourned!\n"""

Path("content").mkdir(parents=True, exist_ok=True)

p = Path(f"content/{meeting_title}.txt")
p.write_text(meeting_text, encoding="utf-8")

# ----Run chain------------------------
response = chain.invoke({"title": meeting_title})
print(response)
# Out:
# Action items saved to content/Business Meeting 2025-05-01: Action Items.txt

# %% [markdown]
# ## **Parallel Processing**
# Runs multiple independent operations simultaneously.

# %%
# Instantiate LLM 
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.2)

# ----Define prompt templates------------------------
summarize_template = ChatPromptTemplate.from_messages([
    ("system", "You are a meeting summarizer."),
    ("human", "Produce a one-paragraph summary of this transcript:\n\n{text}")
])
action_template = ChatPromptTemplate.from_messages([
    ("system", "You extract action items from a meeting transcript."),
    ("human", "List the action items for this meeting transcript," \
        "as bullet points, each starting with '- ':\n\n{text}")
])
confirmation_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that confirms successful \
                completion of meeting processing tasks."),
    ("human", """
        All processing steps have finished. Here are the details:\n\n

        - Title: {title}
        - Meeting minutes saved to {path}
     
       Send a friendly confirmation to the user that their file has been saved.
    """)
])

# ----Helper functions------------------------
def create_actions(data): 
    response = llm.invoke(
        action_template.format_prompt(text=data["text"]).to_messages()
    ).content.strip()
    action_items = [
        line.strip("- ").strip()
        for line in response.splitlines()
        if line.strip().startswith("-")
    ]

    return {
        "title": data["title"], 
        "actions": action_items
    }

def minutes_to_txt(outputs):
    title = outputs["branches"]["summary"]["title"]
    summary = outputs["branches"]["summary"]["summary"]
    actions = "\n".join(outputs["branches"]["actions"]["actions"])

    # Format string to be written to file
    text = f"""
        Title: {title} \n

        ----Summary----------\n
        {summary}\n\n

        ----Action Items----------\n
        {actions}\n\n 
    """

    # Write minutes 
    p = Path(f"content/{title}: Meeting Minutes.txt")
    p.write_text(text, encoding="utf-8")
    return {
        "path": str(p),
        "title": title
    }

# ----Create runnables------------------------

# Runnables for synthesizing and file-writing 
load_transcript = RunnableLambda(
    lambda inputs: {
        "title": inputs["title"],
        "text":  Path(f"content/{inputs['title']}.txt").read_text(encoding="utf-8")
    }
)
summarize_transcript = RunnableLambda(
    lambda inputs: {
        "title":   inputs["title"],
        "summary": llm.invoke(
            summarize_template.format_prompt(text=inputs["text"]).to_messages()
        ).content.strip()
    }
) # could also have used a helper function  
extract_actions = RunnableLambda(create_actions)
write_minutes = RunnableLambda(minutes_to_txt)

# Runnable for LLM confirmation to user
respond_to_user  = RunnableLambda(
    lambda response: llm.invoke(
        confirmation_template.format_prompt(
            title=response["title"],
            path=response["path"],
        )
        .to_messages()
    ).content.strip()
)

# Bundle meeting-synthesizing runnables for parallel processing
synthesize_meeting = RunnableParallel(
    branches={ 
        "summary": load_transcript | summarize_transcript,
        "actions": load_transcript | extract_actions,
    }
)

# ----Assemble chain------------------------
full_pipeline = synthesize_meeting | write_minutes | respond_to_user

# ----Generate txt file------------------------
meeting_title = "Business Meeting 2025-05-01"
meeting_text = """Alice: Good morning, team. Let's get started on our Q3 marketing campaign planning. \n Bob: Morning, Alice. First up, we need to finalize the campaign budget. I've drafted a spreadsheet with three scenarios (low, medium, high spend) and emailed it to everyone. \n Charlie: Got it—Bob, can you share that in the #marketing Slack channel by end of day? \nBob: Yes, I'll post it there by 5 PM today.\n Alice: Great. Next, social media strategy. Dana, you were going to propose some new platforms for influencer outreach?\n Dana: Right. I'm evaluating two micr\n Emily: On it. I'll draft initial outreach emails and share a template by Thursday.\n Alice: Finally, we need copy for the landing page. Frank, can you write the first draft?\n Frank: I'll draft the copy by Monday morning and circulate it for feedback.\n Alice: Awesome. Let's recap action items:\n - **Bob**: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.\n  - **Dana**: Deliver influencer-network recommendation deck by Wednesday.\n  - **Emily**: Share outreach email template by Thursday.\n    - **Frank**: Draft landing-page copy by Monday morning.\n  \nThanks, everyone—meeting adjourned!\n"""

Path("content").mkdir(parents=True, exist_ok=True)

p = Path(f"content/{meeting_title}.txt")
p.write_text(meeting_text, encoding="utf-8")

# ----Run pipeline------------------------
results = full_pipeline.invoke({"title": meeting_title})
print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 114
#     111 meeting_text = """Alice: Good morning, team. Let's get started on our Q3 marketing campaign planning. \n Bob: Morning, Alice. First up, we need to finalize the campaign budget. I've drafted a spreadsheet with three scenarios (low, medium, high spend) and emailed it to everyone. \n Charlie: Got it—Bob, can you share that in the #marketing Slack channel by end of day? \nBob: Yes, I'll post it there by 5 PM today.\n Alice: Great. Next, social media strategy. Dana, you were going to propose some new platforms for influencer outreach?\n Dana: Right. I'm evaluating two micr\n Emily: On it. I'll draft initial outreach emails and share a template by Thursday.\n Alice: Finally, we need copy for the landing page. Frank, can you write the first draft?\n Frank: I'll draft the copy by Monday morning and circulate it for feedback.\n Alice: Awesome. Let's recap action items:\n - **Bob**: Post budget scenarios spreadsheet to #marketing Slack by 5 PM today.\n  - **Dana**: Deliver influencer-network recommendation deck by Wednesday.\n  - **Emily**: Share outreach email template by Thursday.\n    - **Frank**: Draft landing-page copy by Monday morning.\n  \nThanks, everyone—meeting adjourned!\n"""
#     113 p = Path(f"content/{meeting_title}.txt")
# --> 114 p.write_text(meeting_text, encoding="utf-8")
#     116 # ----Run pipeline------------------------
#     117 results = full_pipeline.invoke({"title": meeting_title})
#
# File /usr/lib/python3.11/pathlib.py:1078, in Path.write_text(self, data, encoding, errors, newline)
#    1075     raise TypeError('data must be str, not %s' %
#    1076                     data.__class__.__name__)
#    1077 encoding = io.text_encoding(encoding)
# -> 1078 with self.open(mode='w', encoding=encoding, errors=errors, newline=newline) as f:
#    1079     return f.write(data)
#
# File /usr/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'content/Business Meeting 2025-05-01.txt'

# %% [markdown]
# ## **Branching Processing**
# Handles dynamic decision-making, enabling adaptive workflows.

# %%
# Instantiate LLM 
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.2)

# ----Define prompt templates------------------------
summarize_template = ChatPromptTemplate.from_messages([
    ("system", "You are a meeting summarizer."),
    ("human", "Produce a one-paragraph summary of this transcript:\n\n{text}")
])
action_template = ChatPromptTemplate.from_messages([
    ("system", "You extract action items from a meeting transcript."),
    ("human", "List the action items for this meeting transcript," \
        "as bullet points, each starting with '- ':\n\n{text}")
])
confirmation_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that confirms successful \
                completion of meeting processing tasks."),
    ("human", """
        All processing steps have finished. Here are the details:\n\n

        - Title: {title}
        - {task_completed} saved to {path}
     
       Send a friendly confirmation to the user that their file has been saved.
    """)
])

# ----Helper functions------------------------
def create_action_items(inputs): 
    response = llm.invoke(
        action_template.format_prompt(text=inputs["text"]).to_messages()
    ).content.strip()
    action_items = [
        line.strip("- ").strip()
        for line in response.splitlines()
        if line.strip().startswith("-")
    ]

    return {
        "title": inputs["title"], 
        "actions": action_items, 
        "meeting_class": inputs["meeting_class"]
    }

def classify_meeting(inputs): 
    title = inputs["title"]
    if "Status" in title: 
        meeting_class = "status"
    elif "Planning" in title: 
        meeting_class = "planning"
    else: 
        meeting_class = "retro"
    
    return {**inputs, "meeting_class": meeting_class}

def summary_to_txt(outputs): 
    title = outputs["title"]
    summary = outputs["summary"]
    meeting_class = outputs["meeting_class"]

    # Write summary 
    p = Path(f"content/{meeting_class}/{title}: Summary.txt")
    p.write_text(summary, encoding="utf-8")
    return {
        "path": str(p),
        "title": title,
        "task_completed": "Meeting Summary"
    }

def actions_to_txt(outputs): 
    title = outputs["title"]
    actions = "\n".join(outputs["actions"])
    meeting_class = outputs["meeting_class"]

    # Write actions 
    p = Path(f"content/{meeting_class}/{title}: Action Items.txt")
    p.write_text(actions, encoding="utf-8")
    return {
        "path": str(p),
        "title": title,
        "task_completed": "Meeting Action Items"
    }

def minutes_to_txt(outputs):
    title = outputs["branches"]["summary"]["title"]
    summary = outputs["branches"]["summary"]["summary"]
    actions = "\n".join(outputs["branches"]["actions"]["actions"])
    meeting_class = outputs["branches"]["summary"]["meeting_class"]

    # Format string to be written to file
    text = f"""
        Title: {title} \n

        ----Summary----------\n
        {summary}\n\n

        ----Action Items----------\n
        {actions}\n\n 
    """

    # Write minutes 
    p = Path(f"content/{meeting_class}/{title}: Meeting Minutes.txt")
    p.write_text(text, encoding="utf-8")
    return {
        "path": str(p),
        "title": title,
        "task_completed": "Meeting Minutes"

    }

# ----Create runnables------------------------

# Runnables for synthesizing and file-writing 
load_transcript = RunnableLambda(
    lambda inputs: {
        "title": inputs["title"],
        "text":  Path(f"content/data/{inputs['title']}.txt").read_text(encoding="utf-8"), 
    }
)
summarize_transcript = RunnableLambda(
    lambda inputs: {
        "title":   inputs["title"],
        "summary": llm.invoke(
            summarize_template.format_prompt(text=inputs["text"]).to_messages()
        ).content.strip(),
        "meeting_class": inputs["meeting_class"]
    }
) 
extract_action_items = RunnableLambda(create_action_items)

# Runnable for LLM confirmation to user
respond_to_user  = RunnableLambda(
    lambda response: llm.invoke(
        confirmation_template.format_prompt(
            title=response["title"],
            path=response["path"],
            task_completed=response["task_completed"]
        )
        .to_messages()
    ).content.strip()
)

# Parallel processing for retrospective meeting
synthesize_meeting = RunnableParallel(
    branches={ 
        "summary": summarize_transcript,
        "actions": extract_action_items,
    }
)

# Classify meeting based on title
determine_meeting_class = RunnableLambda(classify_meeting)

# Writers 
status_writer = RunnableLambda(lambda d: summary_to_txt(d))
planning_writer = RunnableLambda(lambda d: actions_to_txt(d))
retro_writer    = RunnableLambda(lambda d: minutes_to_txt(d))

# Determine how to process transcript based on meeting class
brancher = RunnableBranch(
    (lambda d: d["meeting_class"]=="status", summarize_transcript | status_writer),
    (lambda d: d["meeting_class"]=="planning", extract_action_items | planning_writer),
    (lambda d: d["meeting_class"]=="retro", synthesize_meeting | retro_writer),
    synthesize_meeting | retro_writer # default
)

# ----Assemble chain------------------------
full_pipeline = RunnableSequence(
    first=load_transcript, 
    middle=[determine_meeting_class, brancher], 
    last=respond_to_user
)

# ----Generate data------------------------
meeting_transcripts = [
    {
        "title": "Status Meeting 2025-06-01",
        "transcript": """Alice (PM): Let's do our daily status—what did everyone complete yesterday?  
                    Bob (Eng): I finished the caching layer and wrote unit tests.  
                    Carol (QA): I ran the new tests, found two edge-case failures.  
                    Dave (UX): I updated the loading spinner per feedback.  
                    Alice: Great. Action items: Bob to fix edge cases; Carol to re-test; Dave to push spinner update."""
    },
    {
        "title": "Status Meeting 2025-06-02",
        "transcript": """Alice (PM): Quick round—blockers?  
                        Bob (Eng): Still debugging the API rate-limit errors.  
                        Carol (QA): I need test data for the new webhook flows.  
                        Dave (UX): Ready for review on the mobile layout.  
                        Alice: Action items: Bob to pair with Carol on API fixes; Carol to generate test data; Dave to demo layout tomorrow."""
    },

    {
        "title": "Planning Meeting 2025-06-03",
        "transcript": """Alice (PM): Let's plan sprint 12. Top priorities?  
                        Bob (Eng): Finish offline-mode caching, start analytics dashboard.  
                        Carol (QA): We should reserve time for performance testing.  
                        Dave (UX): I'll prototype the dashboard wireframes.  
                        Alice: Action items: Bob to break tasks into tickets; Carol to draft test plan; Dave to deliver wireframes by Friday."""
    },
    {
        "title": "Planning Meeting 2025-06-04",
        "transcript": """Alice (PM): Next week we onboard two interns. We need mentorship tasks.  
                        Bob (Eng): They could help with writing integration tests.  
                        Carol (QA): They can also assist in cross-browser test matrix.  
                        Dave (UX): I'll create style-guide docs for them.  
                        Alice: Action items: Bob to draft test-writing guide; Carol to outline test matrix; Dave to publish style guide."""
    },
    {
        "title": "Retro Meeting 2025-06-05",
        "transcript": """Alice (PM): What went well this sprint?  
                        Bob (Eng): The caching layer shipped smoothly.  
                        Carol (QA): Automation coverage improved by 15%.  
                        Dave (UX): Users loved the updated spinner.  
                        Alice: What didn't go well?  
                        Bob: We underestimated API rate limits.  
                        Carol: Test data lagged behind feature dev.  
                        Alice: Action items: add API-limit tickets; build test-data pipeline."""
    },
    {
        "title": "Retro Meeting 2025-06-06",
        "transcript": """Alice (PM): Sprint 11 retrospective. Wins?  
                        Bob (Eng): Dashboard backend was stable.  
                        Carol (QA): No major regressions.  
                        Dave (UX): Positive user feedback on UI.  
                        Alice: Lows?  
                        Bob: Merge conflicts slowed us down.  
                        Carol: Env setup was flaky.  
                        Alice: Action items: improve branching strategy; stabilize test environments."""
    },
]

# Populate data directory 
Path(f"content/data").mkdir(parents=True, exist_ok=True)
for meeting in meeting_transcripts: 
    p = Path(f"content/data/{meeting['title']}.txt")
    p.write_text(meeting["transcript"], encoding="utf-8")

# Create output directories
for meeting_class in ["status", "planning", "retro"]: 
    Path(f"content/{meeting_class}").mkdir(parents=True, exist_ok=True)

# ----Run pipeline------------------------
for meeting in meeting_transcripts: 
    results = full_pipeline.invoke({"title": meeting["title"]})
    print(results)
# Out:
# Great news!  Your "Status Meeting 2025-06-01" summary has been successfully saved to `content/status/Status Meeting 2025-06-01: Summary.txt`.
# Great news!  Your "Status Meeting 2025-06-02" summary has been successfully saved to `content/status/Status Meeting 2025-06-02: Summary.txt`.
# Great news!  Your "Planning Meeting 2025-06-03" file, including its action items, has been successfully processed and saved to `content/planning/Planning Meeting 2025-06-03: Action Items.txt`.
# Great news!  Your "Planning Meeting 2025-06-04" file, including its action items, has been successfully processed and saved to content/planning/Planning Meeting 2025-06-04: Action Items.txt.
# Great news!  Your Retro Meeting (2025-06-05) minutes have been successfully saved to `content/retro/Retro Meeting 2025-06-05: Meeting Minutes.txt`.
# Great news!  Your Retro Meeting 2025-06-06 minutes have been successfully saved to `content/retro/Retro Meeting 2025-06-06: Meeting Minutes.txt`.

# %% [markdown]
# ## **Improvements to think about....**
#
# - Processing all files in parallel
# - Dynamically classifying files - what are pros and cons of this approach?
#
# ```bash
# classify_meeting_template = ChatPromptTemplate.from_messages([
#   ("system","You are a meeting-type classifier."),
#   ("human","Classify this as status, planning, or retrospective:\n\n{text}")
# ])
# ....
